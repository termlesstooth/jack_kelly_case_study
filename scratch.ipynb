# %%
import pandas as pd

# %%
data = pd.read_csv('data/case_study_data.csv',skiprows=2).iloc[:, 1:]
data = data.dropna(how="all")
data.head()
# Out:
#             Name                                        Description  \
# 1     Automax AI           AI Assistants For Real Estate Appraisers
# 2         Barker                     Insurance Pricing Data Fintech
# 3      Bluespine  AI Platform For Health Insurance Claim Review ...
# 4  Cardinal Gray                  AI Titling Tools For Auto Lenders
# 5    Case Health       AI Automation For Health Plan Authorizations
#
#                   URL            Industry     Stage
# 1          automax.ai            Proptech  Pre-Seed
# 2  thebarkerprice.com  Financial Services      Seed
# 3        bluespine.io          Healthtech      Seed
# 4    cardinalgray.com  Financial Services      Seed
# 5       casehealth.ai          Healthtech  Pre-Seed

# %%
data.iloc[20:50] #row 38 and 39 are weird TODO: Think about productionalizing this
# Out:
#                 Name                                        Description  \
# 21      PixieDust AI        Sales Automation For Small Business Lenders
# 22            Prefix    Repair And Maintenance Software For Restaurants
# 23   Raise Financial                401K Investment Leveraging Platform
# 24            Reveel  Payment Infrastructure For The Collaboration E...
# 25             Rosie                    AI And Human Childcare Platform
# 26        Routesense      Smarter Payments Platform For Risk Management
# 27           Scam AI             AI Scam Detection And Deepfake Defense
# 28      SilkRoute AI           AI Procurement And Supply Chain Platform
# 29        Somethings    Wellness Platform Connecting Youth With Mentors
# 30             Sorce                              Job Matching Platform
# 31            Tesser                  Stablecoin Payment Infrastructure
# 32              Tufa  Investment Platform For Home Purchases Using S...
# ...
